# %% [markdown]
# # Autoencoder
#
# As we learned that Autoencoder is an unsupervised artificial neural network that learns how to efficiently compress and encode data. In artifical intelligence, Data compression is a big topic that’s used in computer vision, computer networks, computer architecture, and many other fields.
#
# The point of data compression is to convert our input into a smaller representation that we recreate, to a degree of quality.  This smaller representation is what would be passed around, and, when anyone needed the original, they would reconstruct it from the smaller representation. Additionally, in almost all contexts where the term "autoencoder" is used, the compression and decompression functions are implemented with neural networks.

# %%
from IPython.display import Image
Image(filename="C:/Users/kk/auto5.jpg", width=800, height= 800)

# %% [markdown]
# - ##### The Upper one are the Original ones
# - ##### The lower one  are the Reconstructed

# %% [markdown]
# # What are autoencoders good for?
#
# One of the most used practical applications of autoencoders are **data denoising** and **dimensionality reduction for data visualization**. With appropriate dimensionality and sparsity constraints, autoencoders can learn data projections that are more interesting than PCA or other basic techniques.
#
#
# ##  Autoencoder Properties
# - An autoencoder doesn’t have to learn dense layers, it can use convolutional layers to learn too, which could be better for video, image and series data.
# - An autoencoder gives a representation as the output of each layer, and maybe having multiple representations of different dimensions is useful.
# - An autoencoder could let you make use of pretrained layers from another model, to apply transfer learning to prime the encoder/decoder.

# %% [markdown]
# ## Autoencoder vs PCA
#
# - Although autoencoder is quite similar to PCA but its Autoencoders are much more flexible than PCA. Autoencoders can represent both liners and non-linar transformation in encoding but PCA can only perform linear transformation.
#
# - Autoencoders can be layered to form deep learning network due to it’s Network representation.Autoencoder provides a more accurate output when compared to PCA.

# %% [markdown]
# ## Types of autoencoder :
#
# We will discuess these 4 type of autoencoder:
# 1. Vanilla autoencoder
# 2. Multilayer autoencoder
# 3. Convolutional autoencoder
# 4. Regularized autoencoder

# %% [markdown]
# ### Vanilla autoencoder:
# Vanilla autoencoder is a three layers neural net, a neural net with one hidden layer. The input and output are the same, and we learn how to reconstruct the input, for example using the adam optimizer and the mean squared error loss function.

# %% [markdown]
# ### Multilayer autoencoder:
# If one hidden layer is not enough, we can obviously extend the autoencoder to more hidden layers. Hidden layers can be picked as the feature representation but we will make the network symmetrical and use the middle-most layer.

# %% [markdown]
# ### Convolutional autoencoder:
# In convolutional autoencoder The input image is downsampled to give a latent representation of smaller dimensions and force the autoencoder to learn a compressed version of the images.

# %% [markdown]
# ### Regularized autoencoder:
# Regularized autoencoders use a loss function that encourages the model to have other properties besides the ability to copy its input to its output.

# %% [markdown]
# ## Autoencoder Components:
#
# Autoencoders consists of 4 main parts:

# %%
from IPython.display import Image
Image(filename="C:/Users/kk/AUTO2.png", width=400, height= 400)

# %% [markdown]
# -  Encoder: This is the part of the network that compresses the input into a latent space representation. The encoder layer encodes the input image as a compressed representation in a reduced dimension. The compressed image typically looks garbled, nothing like the original image
#
# -  Bottleneck: Which is the layer that contains the compressed representation of the input data. This is the lowest possible dimensions of the input data.
#
# - Decoder: This layer decodes the encoded image back to the original dimension. The decoded image is a lossy reconstruction of the original image. It reconstructs the input from the latent space representation.

# %%
from IPython.display import Image
Image(filename="C:/Users/kk/AUTO3.png", width=400, height= 400)

# %% [markdown]
# ``` Block example of encoding and decoding using an autoencoder```
#
# - Reconstruction Loss: This is the method that measures measure how well the decoder is performing and how close the output is to the original input.

# %% [markdown]
# ## Some Applications of Autoencoders:
#
# ##### Denoising Image:
#
# - Denoising or noise reduction is the process of removing noise from a signal. This can be an image, audio or a document. You can train an Autoencoder network to learn how to remove noise from pictures.
#
# - During the training, the autoencoder learns to extract important features from input images and ignores the image noises because the labels have no noises. the input seen by the autoencoder is not the raw input but a stochastically corrupted version. A denoising autoencoder is thus trained to reconstruct the original input from the noisy version.
#
# - Here we are donoising using MNIST dataset>>

# %%
from IPython.display import Image
Image(filename="C:/Users/kk/AUTO4.jpeg", width=400, height= 400)

# %% [markdown]
# - Here, another example of denoising
#
# - #####  (Noised Image)

# %%
from IPython.display import Image
Image(filename="C:/Users/kk/AUTO6.JPG", width=400, height= 400)

# %% [markdown]
# - #####  (De-Noised Image)

# %%
from IPython.display import Image
Image(filename="C:/Users/kk/AUTO7.JPG", width=400, height= 400)

# %% [markdown]
# - ##### ( Image Without Noise)

# %%
from IPython.display import Image
Image(filename="C:/Users/kk/AUTO8.JPG", width=400, height= 400)

# %% [markdown]
# ##### Feature variation:
# - It extracts only the required features of an image and generates the output by removing any noise or unnecessary interruption.
#
# ##### Watermark Removal:
# - It is also used for removing watermarks from images or to remove any object while filming a video or a movie.
